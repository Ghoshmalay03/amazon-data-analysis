# %% [markdown]
# import pandas as pd
#
# df = pd.read_csv('amazon.csv')
#
# print(df.head())

# %%
print(df.shape)
# Out:
# (1465, 16)

# %%
print(df.columns)
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='str')

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   str
#  1   product_name         1465 non-null   str
#  2   category             1465 non-null   str
#  3   discounted_price     1465 non-null   str
#  4   actual_price         1465 non-null   str
#  5   discount_percentage  1465 non-null   str
#  6   rating               1465 non-null   str
#  7   rating_count         1463 non-null   str
#  8   about_product        1465 non-null   str
#  9   user_id              1465 non-null   str
#  10  user_name            1465 non-null   str
#  11  review_id            1465 non-null   str
#  12  review_title         1465 non-null   str
#  13  review_content       1465 non-null   str
#  14  img_link             1465 non-null   str
#  15  product_link         1465 non-null   str
# dtypes: str(16)
# ...

# %%
print(df.isnull().sum())
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/amazon.csv')

print(df.head())
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   str
#  1   product_name         1465 non-null   str
#  2   category             1465 non-null   str
#  3   discounted_price     1465 non-null   str
#  4   actual_price         1465 non-null   str
#  5   discount_percentage  1465 non-null   str
#  6   rating               1465 non-null   str
#  7   rating_count         1463 non-null   str
#  8   about_product        1465 non-null   str
#  9   user_id              1465 non-null   str
#  10  user_name            1465 non-null   str
#  11  review_id            1465 non-null   str
#  12  review_title         1465 non-null   str
#  13  review_content       1465 non-null   str
#  14  img_link             1465 non-null   str
#  15  product_link         1465 non-null   str
# dtypes: str(16)
# ...

# %%
print(df.describe())
# Out:
#         product_id                                       product_name  \
# count         1465                                               1465
# unique        1351                                               1337
# top     B07JW9H4J1  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# freq             3                                                  5
#
#                                                  category discounted_price  \
# count                                                1465             1465
# unique                                                211              550
# top     Computers&Accessories|Accessories&Peripherals|...             ₹199
# freq                                                  233               53
#
#        actual_price discount_percentage rating rating_count  \
# count          1465                1465   1465         1463
# unique          449                  92     28         1143
# ...

# %%
print(df.columns)
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='str')

# %%
df.columns = df.columns.str.strip()

# %%
print(df.isnull().sum())
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
print(df['Sales'].sum())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
print(df['amazon'].sum())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
print(df.columns.tolist())
# Out:
# ['product_id', 'product_name', 'category', 'discounted_price', 'actual_price', 'discount_percentage', 'rating', 'rating_count', 'about_product', 'user_id', 'user_name', 'review_id', 'review_title', 'review_content', 'img_link', 'product_link']

# %%
print(df.head())
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
print(df.dtypes)
# Out:
# product_id             str
# product_name           str
# category               str
# discounted_price       str
# actual_price           str
# discount_percentage    str
# rating                 str
# rating_count           str
# about_product          str
# user_id                str
# user_name              str
# review_id              str
# review_title           str
# review_content         str
# img_link               str
# product_link           str
# dtype: object

# %%
df['discounted_price'] = df['discounted_price'].str.replace('₹', '')
df['discounted_price'] = df['discounted_price'].str.replace(',', '')
df['discounted_price'] = df['discounted_price'].astype(float)

df['actual_price'] = df['actual_price'].str.replace('₹', '')
df['actual_price'] = df['actual_price'].str.replace(',', '')
df['actual_price'] = df['actual_price'].astype(float)

# %%
df['rating_count'] = df['rating_count'].str.replace(',', '')
df['rating_count'] = pd.to_numeric(df['rating_count'], errors='coerce')

# %%
print(df.dtypes)
# Out:
# product_id                 str
# product_name               str
# category                   str
# discounted_price       float64
# actual_price           float64
# discount_percentage        str
# rating                     str
# rating_count           float64
# about_product              str
# user_id                    str
# user_name                  str
# review_id                  str
# review_title               str
# review_content             str
# img_link                   str
# product_link               str
# dtype: object

# %%
print(df['rating'].mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 print(df['rating'].mean())
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\series.py:8113, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    8063 @deprecate_nonkeyword_arguments(Pandas4Warning, allowed_args=["self"], name="mean")
#    8064 def mean(
#    8065     self,
#    (...)   8069     **kwargs,
# ...

# %%
print(df['rating'].unique())
# Out:
# <StringArray>
# ['4.2', '4.0', '3.9', '4.1', '4.3', '4.4', '4.5', '3.7', '3.3', '3.6', '3.4',
#  '3.8', '3.5', '4.6', '3.2', '5.0', '4.7', '3.0', '2.8',   '4', '3.1', '4.8',
#  '2.3',   '|',   '2',   '3', '2.6', '2.9']
# Length: 28, dtype: str

# %%
df['rating'] = pd.to_numeric(df['rating'], errors='coerce')

# %%
print(df['rating'].dtype)
# Out:
# float64

# %%
print(df['rating'].mean())
# Out:
# 4.096584699453552

# %%
print(df.describe())
# Out:
#        discounted_price   actual_price       rating   rating_count
# count       1465.000000    1465.000000  1464.000000    1463.000000
# mean        3125.310874    5444.990635     4.096585   18295.541353
# std         6944.304394   10874.826864     0.291674   42753.864952
# min           39.000000      39.000000     2.000000       2.000000
# 25%          325.000000     800.000000     4.000000    1186.000000
# 50%          799.000000    1650.000000     4.100000    5179.000000
# 75%         1999.000000    4295.000000     4.300000   17336.500000
# max        77990.000000  139900.000000     5.000000  426973.000000

# %%
print(df['Sales'].sum())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
print(df.describe())
# Out:
#        discounted_price   actual_price       rating   rating_count
# count       1465.000000    1465.000000  1464.000000    1463.000000
# mean        3125.310874    5444.990635     4.096585   18295.541353
# std         6944.304394   10874.826864     0.291674   42753.864952
# min           39.000000      39.000000     2.000000       2.000000
# 25%          325.000000     800.000000     4.000000    1186.000000
# 50%          799.000000    1650.000000     4.100000    5179.000000
# 75%         1999.000000    4295.000000     4.300000   17336.500000
# max        77990.000000  139900.000000     5.000000  426973.000000

# %%
print(df.isnull().sum())
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 1
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
df['rating'] = pd.to_numeric(df['rating'], errors='coerce')

# %%
print(df['rating'].dtype)
# Out:
# float64

# %%
print(df['rating'].mean())
# Out:
# 4.096584699453552

# %%
top_rated = df[['product_name', 'rating']]

print(top_rated.sort_values(by='rating', ascending=False).head(10))
# Out:
#                                            product_name  rating
# 174   Syncwire LTG to USB Cable for Fast Charging Co...     5.0
# 324   REDTECH USB-C to Lightning Cable 3.3FT, [Apple...     5.0
# 775   Amazon Basics Wireless Mouse | 2.4 GHz Connect...     5.0
# 1299  Instant Pot Air Fryer, Vortex 2QT, Touch Contr...     4.8
# 1201  Oratech Coffee Frother electric, milk frother ...     4.8
# 1145  Swiffer Instant Electric Water Heater Faucet T...     4.8
# 1223  FIGMENT Handheld Milk Frother Rechargeable, 3-...     4.7
# 1226  Zuvexa USB Rechargeable Electric Foam Maker - ...     4.7
# 1275  Multifunctional 2 in 1 Electric Egg Boiling St...     4.7
# 459   Spigen EZ Fit Tempered Glass Screen Protector ...     4.7

# %%
print(df['category'].value_counts().head(10))
# Out:
# category
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables                        233
# Electronics|WearableTechnology|SmartWatches                                                               76
# Electronics|Mobiles&Accessories|Smartphones&BasicMobiles|Smartphones                                      68
# Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions                                             63
# Electronics|Headphones,Earbuds&Accessories|Headphones|In-Ear                                              52
# Electronics|HomeTheater,TV&Video|Accessories|RemoteControls                                               49
# Home&Kitchen|Kitchen&HomeAppliances|SmallKitchenAppliances|MixerGrinders                                  27
# Electronics|HomeTheater,TV&Video|Accessories|Cables|HDMICables                                            24
# ...

# %%
df['category'].value_counts().head(10).plot(kind='bar')

plt.title('Top Product Categories')
plt.xlabel('Category')
plt.ylabel('Number of Products')

plt.show()
# Out:
# Task was destroyed but it is pending!
# task: <Task pending name='Task-164' coro=<_async_in_context.<locals>.run_in_context() done, defined at C:\Users\malay\AppData\Local\Programs\Python\Python314\Lib\site-packages\ipykernel\utils.py:57> wait_for=<Task pending name='Task-165' coro=<Kernel.shell_main() running at C:\Users\malay\AppData\Local\Programs\Python\Python314\Lib\site-packages\ipykernel\kernelbase.py:597> cb=[Task.task_wakeup()]> cb=[ZMQStream._run_callback.<locals>._log_error() at C:\Users\malay\AppData\Local\Programs\Python\Python314\Lib\site-packages\zmq\eventloop\zmqstream.py:563]>
# C:\Users\malay\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\plotting\_matplotlib\boxplot.py:26: RuntimeWarning: coroutine 'Kernel.shell_main' was never awaited
#   from pandas.plotting._matplotlib.core import (
# ...
# Task was destroyed but it is pending!
# ...

# %%
df['category'].value_counts().head(10).plot(kind='bar')

plt.title('Top Product Categories')
plt.xlabel('Category')
plt.ylabel('Number of Products')

plt.show()

# %%
sns.histplot(df['rating'], bins=20)

plt.title('Distribution of Product Ratings')

plt.show()

# %%
df['discount_percentage'] = (
    df['discount_percentage']
    .str.replace('%', '')
    .astype(float)
)

# %%
print(df['discount_percentage'].mean())
# Out:
# 47.69146757679181

# %%
sns.histplot(df['discount_percentage'], bins=20)

plt.title('Discount Percentage Distribution')

plt.show()

# %%
plt.savefig('top_categories.png')

# %%
top_rated = df[['product_name', 'rating']]

top_rated = top_rated.sort_values(
    by='rating',
    ascending=False
)

print(top_rated.head(10))
# Out:
#                                            product_name  rating
# 174   Syncwire LTG to USB Cable for Fast Charging Co...     5.0
# 324   REDTECH USB-C to Lightning Cable 3.3FT, [Apple...     5.0
# 775   Amazon Basics Wireless Mouse | 2.4 GHz Connect...     5.0
# 1299  Instant Pot Air Fryer, Vortex 2QT, Touch Contr...     4.8
# 1201  Oratech Coffee Frother electric, milk frother ...     4.8
# 1145  Swiffer Instant Electric Water Heater Faucet T...     4.8
# 1223  FIGMENT Handheld Milk Frother Rechargeable, 3-...     4.7
# 1226  Zuvexa USB Rechargeable Electric Foam Maker - ...     4.7
# 1275  Multifunctional 2 in 1 Electric Egg Boiling St...     4.7
# 459   Spigen EZ Fit Tempered Glass Screen Protector ...     4.7

# %%
expensive_products = df[['product_name', 'actual_price']]

expensive_products = expensive_products.sort_values(
    by='actual_price',
    ascending=False
)

print(expensive_products.head(10))
# Out:
#                                            product_name  actual_price
# 249   Sony Bravia 164 cm (65 inches) 4K Ultra HD Sma...      139900.0
# 255   VU 164 cm (65 inches) The GloLED Series 4K Sma...       85000.0
# 283   LG 139 cm (55 inches) 4K Ultra HD Smart LED TV...       79990.0
# 1354  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...       75990.0
# 568   Samsung Galaxy S20 FE 5G (Cloud Navy, 8GB RAM,...       74999.0
# 192   Samsung 138 cm (55 inches) Crystal 4K Neo Seri...       70900.0
# 325   OnePlus 163.8 cm (65 inches) U Series 4K LED S...       69999.0
# 332   MI 138.8 cm (55 inches) 5X Series 4K Ultra HD ...       69999.0
# 276   Samsung 138 cm (55 inches) Crystal 4K Series U...       69900.0
# 108   VU 139 cm (55 inches) The GloLED Series 4K Sma...       65000.0

# %%
discounted_products = df[['product_name', 'discount_percentage']]

discounted_products = discounted_products.sort_values(
    by='discount_percentage',
    ascending=False
)

print(discounted_products.head(10))
# Out:
#                                           product_name  discount_percentage
# 695  rts [2 Pack] Mini USB C Type C Adapter Plug, T...                 94.0
# 372  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...                 91.0
# 380  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...                 91.0
# 364  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...                 91.0
# 368  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...                 91.0
# 334  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...                 91.0
# 557  LAPSTER 12pcs Spiral Cable Protectors for Char...                 90.0
# 920  Silicone Rubber Earbuds Tips, Eartips, Earpads...                 90.0
# 644  Sounce Spiral Charger Cable Protector Data Cab...                 90.0
# 407  Sounce Spiral Charger Cable Protector Data Cab...                 90.0

# %%
category_count = df['category'].value_counts()

print(category_count.head(10))
# Out:
# category
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables                        233
# Electronics|WearableTechnology|SmartWatches                                                               76
# Electronics|Mobiles&Accessories|Smartphones&BasicMobiles|Smartphones                                      68
# Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions                                             63
# Electronics|Headphones,Earbuds&Accessories|Headphones|In-Ear                                              52
# Electronics|HomeTheater,TV&Video|Accessories|RemoteControls                                               49
# Home&Kitchen|Kitchen&HomeAppliances|SmallKitchenAppliances|MixerGrinders                                  27
# Electronics|HomeTheater,TV&Video|Accessories|Cables|HDMICables                                            24
# ...

# %%
plt.figure(figsize=(10,6))

category_count.head(10).plot(kind='bar')

plt.title('Top 10 Product Categories')
plt.xlabel('Category')
plt.ylabel('Count')

plt.show()

# %%
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# %%
correlation = numeric_df.corr()

print(correlation)
# Out:
#                      discounted_price  actual_price  discount_percentage  \
# discounted_price             1.000000      0.961915            -0.242412
# actual_price                 0.961915      1.000000            -0.118098
# discount_percentage         -0.242412     -0.118098             1.000000
# rating                       0.120337      0.121642            -0.155375
# rating_count                -0.027261     -0.036137             0.011691
#
#                        rating  rating_count
# discounted_price     0.120337     -0.027261
# actual_price         0.121642     -0.036137
# discount_percentage -0.155375      0.011691
# rating               1.000000      0.102235
# rating_count         0.102235      1.000000

# %%
plt.figure(figsize=(8,6))

sns.heatmap(
    correlation,
    annot=True,
    cmap='coolwarm'
)

plt.title('Correlation Heatmap')

plt.show()

# %%
top_reviewed = df[['product_name', 'rating_count']]

top_reviewed = top_reviewed.sort_values(
    by='rating_count',
    ascending=False
)

print(top_reviewed.head(10))
# Out:
#                                           product_name  rating_count
# 47   Amazon Basics High-Speed HDMI Cable, 6 Feet - ...      426973.0
# 65   Amazon Basics High-Speed HDMI Cable, 6 Feet (2...      426973.0
# 12   AmazonBasics Flexible Premium HDMI Cable (Blac...      426973.0
# 684  AmazonBasics Flexible Premium HDMI Cable (Blac...      426972.0
# 400  boAt Bassheads 100 in Ear Wired Earphones with...      363713.0
# 352  boAt Bassheads 100 in Ear Wired Earphones with...      363713.0
# 584  boAt BassHeads 100 in-Ear Wired Headphones wit...      363711.0
# 371  Redmi 9A Sport (Coral Green, 2GB RAM, 32GB Sto...      313836.0
# 370  Redmi 9 Activ (Carbon Black, 4GB RAM, 64GB Sto...      313836.0
# 566  Redmi 9A Sport (Coral Green, 3GB RAM, 32GB Sto...      313832.0

# %%
plt.figure(figsize=(8,6))

sns.scatterplot(
    x='actual_price',
    y='rating',
    data=df
)

plt.title('Price vs Rating')

plt.show()

# %%
## Business Insights

1. Most products belong to Electronics category.
2. Majority of products have ratings above 4.
3. Discounts mainly range between 40%–70%.
4. Highly reviewed products are generally moderately priced.
5. Product ratings are relatively stable across price ranges.
# Out:
#   Cell In[53], line 5
#     3. Discounts mainly range between 40%–70%.
#                                          ^
# SyntaxError: invalid character '–' (U+2013)

# %%
plt.savefig('price_vs_rating.png')

# %%
highest_discount = df[
    ['product_name', 'discount_percentage']
]

highest_discount = highest_discount.sort_values(
    by='discount_percentage',
    ascending=False
)

print(highest_discount.head(10))
# Out:
#                                           product_name  discount_percentage
# 695  rts [2 Pack] Mini USB C Type C Adapter Plug, T...                 94.0
# 372  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...                 91.0
# 380  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...                 91.0
# 364  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...                 91.0
# 368  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...                 91.0
# 334  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...                 91.0
# 557  LAPSTER 12pcs Spiral Cable Protectors for Char...                 90.0
# 920  Silicone Rubber Earbuds Tips, Eartips, Earpads...                 90.0
# 644  Sounce Spiral Charger Cable Protector Data Cab...                 90.0
# 407  Sounce Spiral Charger Cable Protector Data Cab...                 90.0

# %%
plt.figure(figsize=(8,6))

sns.scatterplot(
    x='actual_price',
    y='discounted_price',
    data=df
)

plt.title('Actual Price vs Discounted Price')

plt.show()

# %%
plt.figure(figsize=(8,6))

sns.boxplot(x=df['rating'])

plt.title('Rating Boxplot')

plt.show()

# %%
avg_rating = df.groupby('category')['rating'].mean()

avg_rating = avg_rating.sort_values(
    ascending=False
)

print(avg_rating.head(10))
# Out:
# category
# Computers&Accessories|Tablets                                                                 4.6
# Computers&Accessories|NetworkingDevices|NetworkAdapters|PowerLANAdapters                      4.5
# Electronics|Cameras&Photography|Accessories|Film                                              4.5
# Computers&Accessories|Components|Memory                                                       4.5
# Electronics|HomeAudio|MediaStreamingDevices|StreamingClients                                  4.5
# OfficeProducts|OfficeElectronics|Calculators|Basic                                            4.5
# HomeImprovement|Electrical|CordManagement                                                     4.5
# Home&Kitchen|Kitchen&HomeAppliances|Coffee,Tea&Espresso|CoffeePresses                         4.5
# Home&Kitchen|Kitchen&HomeAppliances|SmallKitchenAppliances|SmallApplianceParts&Accessories    4.5
# ...

# %%
plt.figure(figsize=(10,6))

avg_rating.head(10).plot(kind='bar')

plt.title('Top Categories by Average Rating')
plt.ylabel('Average Rating')

plt.show()

# %%
most_reviewed = df[
    ['product_name', 'rating_count']
]

most_reviewed = most_reviewed.sort_values(
    by='rating_count',
    ascending=False
)

print(most_reviewed.head(10))
# Out:
#                                           product_name  rating_count
# 47   Amazon Basics High-Speed HDMI Cable, 6 Feet - ...      426973.0
# 65   Amazon Basics High-Speed HDMI Cable, 6 Feet (2...      426973.0
# 12   AmazonBasics Flexible Premium HDMI Cable (Blac...      426973.0
# 684  AmazonBasics Flexible Premium HDMI Cable (Blac...      426972.0
# 400  boAt Bassheads 100 in Ear Wired Earphones with...      363713.0
# 352  boAt Bassheads 100 in Ear Wired Earphones with...      363713.0
# 584  boAt BassHeads 100 in-Ear Wired Headphones wit...      363711.0
# 371  Redmi 9A Sport (Coral Green, 2GB RAM, 32GB Sto...      313836.0
# 370  Redmi 9 Activ (Carbon Black, 4GB RAM, 64GB Sto...      313836.0
# 566  Redmi 9A Sport (Coral Green, 3GB RAM, 32GB Sto...      313832.0

# %%
sns.pairplot(
    df[
        [
            'actual_price',
            'discounted_price',
            'discount_percentage',
            'rating'
        ]
    ]
)

plt.show()

# %%
## Final Insights

1. Most products are heavily discounted.
2. Product ratings remain high across categories.
3. Electronics dominate Amazon product listings.
4. Higher discounts do not always guarantee higher ratings.
5. Premium products receive fewer customer reviews.
# Out:
#   Cell In[62], line 3
#     1. Most products are heavily discounted.
#        ^
# SyntaxError: invalid syntax

# %%
df.to_csv('cleaned_amazon_data.csv', index=False)

# %%
plt.savefig('rating_distribution.png')

# %%
plt.savefig('price_vs_rating.png')

# %%
plt.show()

# %%
plt.figure(figsize=(8,6))

sns.scatterplot(
    x='actual_price',
    y='rating',
    data=df
)

plt.title('Price vs Rating')

plt.savefig('price_vs_rating.png')

plt.show()

# %%
plt.savefig(...)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 plt.savefig(...)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\pyplot.py:1250, in savefig(*args, **kwargs)
#    1247 fig = gcf()
#    1248 # savefig default implementation has no return, so mypy is unhappy
#    1249 # presumably this is here because subclasses can return?
# -> 1250 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1251 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1252 return res
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\figure.py:3497, in Figure.savefig(self, fname, transparent, **kwargs)
#    3495     for ax in self.axes:
#    3496         _recursively_make_axes_transparent(stack, ax)
# -> 3497 self.canvas.print_figure(fname, **kwargs)
#
# ...

# %%
plt.show()

# %%
plt.savefig('graphs/price_vs_rating.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 plt.savefig('graphs/price_vs_rating.png')
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\pyplot.py:1250, in savefig(*args, **kwargs)
#    1247 fig = gcf()
#    1248 # savefig default implementation has no return, so mypy is unhappy
#    1249 # presumably this is here because subclasses can return?
# -> 1250 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1251 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1252 return res
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\figure.py:3497, in Figure.savefig(self, fname, transparent, **kwargs)
#    3495     for ax in self.axes:
#    3496         _recursively_make_axes_transparent(stack, ax)
# ...

# %%
plt.figure(figsize=(8,6))

sns.histplot(df['rating'], bins=20)

plt.title('Distribution of Product Ratings')

plt.savefig('rating_distribution.png')

plt.show()

# %%
plt.figure(figsize=(10,6))

category_count.head(10).plot(kind='bar')

plt.title('Top 10 Product Categories')
plt.xlabel('Category')
plt.ylabel('Count')

plt.savefig('top_categories.png')

plt.show()

# %%
plt.savefig('graphs/top_categories.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 plt.savefig('graphs/top_categories.png')
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\pyplot.py:1250, in savefig(*args, **kwargs)
#    1247 fig = gcf()
#    1248 # savefig default implementation has no return, so mypy is unhappy
#    1249 # presumably this is here because subclasses can return?
# -> 1250 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1251 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1252 return res
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\figure.py:3497, in Figure.savefig(self, fname, transparent, **kwargs)
#    3495     for ax in self.axes:
#    3496         _recursively_make_axes_transparent(stack, ax)
# ...

# %%
../graphs/top_categories.png
# Out:
#   Cell In[74], line 1
#     ../graphs/top_categories.png
#     ^
# SyntaxError: invalid syntax

# %%
plt.figure(figsize=(10,6))

category_count.head(10).plot(kind='bar')

plt.title('Top 10 Product Categories')
plt.xlabel('Category')
plt.ylabel('Count')

plt.savefig('../graphs/top_categories.png')

plt.show()

# %%
plt.savefig('graphs/top_categories.png')
# Out:
# --------------------------------------------------
# FileNotFoundErrorTraceback (most recent call last)
# Cell In[76], line 1
# ----> 1 plt.savefig('graphs/top_categories.png')
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\pyplot.py:1250, in savefig(*args, **kwargs)
#    1247 fig = gcf()
#    1248 # savefig default implementation has no return, so mypy is unhappy
#    1249 # presumably this is here because subclasses can return?
# -> 1250 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1251 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1252 return res
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\figure.py:3497, in Figure.savefig(self, fname, transparent, **kwargs)
#    3495     for ax in self.axes:
#    3496         _recursively_make_axes_transparent(stack, ax)
# -> 3497 self.canvas.print_figure(fname, **kwargs)
#
# ...

# %%
plt.savefig('graphs/top_categories.png')
# Out:
# --------------------------------------------------
# FileNotFoundErrorTraceback (most recent call last)
# Cell In[77], line 1
# ----> 1 plt.savefig('graphs/top_categories.png')
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\pyplot.py:1250, in savefig(*args, **kwargs)
#    1247 fig = gcf()
#    1248 # savefig default implementation has no return, so mypy is unhappy
#    1249 # presumably this is here because subclasses can return?
# -> 1250 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1251 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1252 return res
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\figure.py:3497, in Figure.savefig(self, fname, transparent, **kwargs)
#    3495     for ax in self.axes:
#    3496         _recursively_make_axes_transparent(stack, ax)
# -> 3497 self.canvas.print_figure(fname, **kwargs)
#
# ...

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\malay\OneDrive\Desktop\Malay codes\Data Analysis\data

# %%
plt.savefig('../graphs/top_categories.png')

# %%
plt.figure(figsize=(10,6))

category_count.head(10).plot(kind='bar')

plt.title('Top 10 Product Categories')
plt.xlabel('Category')
plt.ylabel('Count')

plt.savefig('../graphs/top_categories.png')

plt.show()

# %%
# Amazon Product Data Analysis

## Objective
Analyze Amazon product pricing, discounts, ratings, and customer reviews to extract business insights.

## Tools Used
- Python
- Pandas
- Matplotlib
- Seaborn
- Jupyter Notebook
# Out:
#   Cell In[1], line 4
#     Analyze Amazon product pricing, discounts, ratings, and customer reviews to extract business insights.
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Amazon Product Data Analysis
#
# ## Objective
# Analyze Amazon product pricing, discounts, ratings, and customer reviews to extract business insights.
#
# ## Tools Used
# - Python
# - Pandas
# - Matplotlib
# - Seaborn
# - Jupyter Notebook

# %% [markdown]
# # Data Loading
# # Data Cleaning
# # Exploratory Data Analysis
# # Visualization
# # Business Insights
# # Conclusion

# %%
numeric_df = df.select_dtypes(include=['float64', 'int64'])

correlation = numeric_df.corr()

plt.figure(figsize=(8,6))

sns.heatmap(
    correlation,
    annot=True,
    cmap='coolwarm'
)

plt.title('Correlation Heatmap')

plt.savefig('graphs/correlation_heatmap.png')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 numeric_df = df.select_dtypes(include=['float64', 'int64'])
#       2
#       3 correlation = numeric_df.corr()
#       4
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/amazon.csv')

# %%
df['discounted_price'] = (
    df['discounted_price']
    .str.replace('₹', '')
    .str.replace(',', '')
    .astype(float)
)

df['actual_price'] = (
    df['actual_price']
    .str.replace('₹', '')
    .str.replace(',', '')
    .astype(float)
)

df['discount_percentage'] = (
    df['discount_percentage']
    .str.replace('%', '')
    .astype(float)
)

df['rating'] = pd.to_numeric(
    df['rating'],
    errors='coerce'
)

df['rating_count'] = (
    df['rating_count']
    .str.replace(',', '')
)

df['rating_count'] = pd.to_numeric(
    df['rating_count'],
    errors='coerce'
)

# %%
numeric_df = df.select_dtypes(
    include=['float64', 'int64']
)

correlation = numeric_df.corr()

plt.figure(figsize=(8,6))

sns.heatmap(
    correlation,
    annot=True,
    cmap='coolwarm'
)

plt.title('Correlation Heatmap')

plt.savefig('graphs/correlation_heatmap.png')

plt.show()

# %%
sns.pairplot(
    df[
        [
            'actual_price',
            'discounted_price',
            'discount_percentage',
            'rating'
        ]
    ]
)

plt.savefig('graphs/pairplot.png')

plt.show()

# %%
top_reviewed = df[
    ['product_name', 'rating_count']
]

top_reviewed = top_reviewed.sort_values(
    by='rating_count',
    ascending=False
)

print(top_reviewed.head(10))
# Out:
#                                           product_name  rating_count
# 47   Amazon Basics High-Speed HDMI Cable, 6 Feet - ...      426973.0
# 65   Amazon Basics High-Speed HDMI Cable, 6 Feet (2...      426973.0
# 12   AmazonBasics Flexible Premium HDMI Cable (Blac...      426973.0
# 684  AmazonBasics Flexible Premium HDMI Cable (Blac...      426972.0
# 400  boAt Bassheads 100 in Ear Wired Earphones with...      363713.0
# 352  boAt Bassheads 100 in Ear Wired Earphones with...      363713.0
# 584  boAt BassHeads 100 in-Ear Wired Headphones wit...      363711.0
# 371  Redmi 9A Sport (Coral Green, 2GB RAM, 32GB Sto...      313836.0
# 370  Redmi 9 Activ (Carbon Black, 4GB RAM, 64GB Sto...      313836.0
# 566  Redmi 9A Sport (Coral Green, 3GB RAM, 32GB Sto...      313832.0

# %% [markdown]
# # Final Insights
#
# 1. Electronics products dominate Amazon listings.
# 2. Most products maintain ratings above 4.
# 3. Discounts mainly range between 40–70%.
# 4. Expensive products receive fewer reviews.
# 5. Heavy discounts do not always improve ratings.
